# %%
class cab_booking_service:
    def info(self,name=""):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\t\t\tHello!",name,"\t\t\t\t\t\twww.lpu_cabservice\n\t\t\t\t\t Welcome to LPU Cab Service")
        print("\t\t\t\t\t(Providing comfort to your Travel)")
        print(Style.RESET_ALL)
    
    def service(self):
        print("\n\t\t\t\t\t\tTYPES OF SERVICE\n")
        print("1. Intercity: Travel other Cities with LPU Cab Services\n")
        print("2. Intracity: Travel comfortly in your City with LPU Cab Services\n")
        print("3. Package: Send or Recieve Packages from your loved ones, family or friends\n\n\n")

    def intercity(self):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\t\t\tWelcome to LPU Intercity Cab Services\n")
        print(Style.RESET_ALL)
        pickup=input("Enter the Pickup Location:")
        drop=input("Enter the Drop Location:")
        x=["LPU Go","LPU Prime Sedan","LPU Premier"]
        y=[50,100,150]
        ic_={"Available Cab":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(ic_)
        print(df)
        f=[]
        while x:
            x=True
            p=int(input("Enter the Postion of available cab:"))
            d=int(input("Enter the Distance"))
            z=ic_["Price"][p]
            y=z*d
            f.append(y)
            s=input("Enter any instruction you want to give to driver:")
            e=input("Do you want to book a cab again(yes\no)")
            if e=="no":
                print("Thank YOU")
            break
        t=sum(f)
        from colorama import Fore,Back,Style
        print(Fore.BLACK,Back.YELLOW,Style.BRIGHT,"Pickup Location:",pickup,"\nDrop Location:",drop)
        print("Instruction to driver:",s)
        print("Your Total charge is:",t)
        print("Please Pay",t,"rupees")
        print("THNAK YOU FOR CHOOSING LPU CAB SERVICES")
        print(Style.RESET_ALL)
    
    def intracity(self):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\t\tWelcome to LPU Package Services\n")
        print(Style.RESET_ALL)
        pickup=input("Enter the Pickup Location:")
        drop=input("Enter the Drop Location:")
        x=["LPU Go","LPU Auto","LPU Bike"]
        y=[70,50,30]
        ic_={"Available cab":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(ic_)
        print(df)
        f=[]
        while x:
            x=True
            p=int(input("Enter the Position of Available cab"))
            d=int(input("Enter the Distance"))
            z=ic_["Price"][p]
            y=z*d
            f.append(y)
            s=input("Enter the Instruction to Driver:")
            e=input("Do you want to book a cab again(yes/no)")
            if e=="no":
                print("THANK YOU")
                break
        t=sum(f)
        from colorama import Fore,Back,Style
        print(Fore.BLACK,Back.YELLOW,Style.BRIGHT,"Pickup Location:",pickup,"\nDrop Location:",drop)
        print("Instructions to driver:",s)
        print("Your Total Charge is:",t)
        print("Please Pay",t,"rupees")
        print("TTHANK YOU FOR CHOOSING LPU CAB SERVICES")
        print(Style.RESET_ALL)   
    
    def package(self):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\tWelcome to LPU Package Service\n")
        print(Style.RESET_ALL)
        a=input("Do you want to send or receive a package")
        if a=="send":
            pickup=input("Enter the your Address:")
            drop=input("Enter the Receiver's Adddress:")
            x=["0-5","5-10","10-15","15-20","20-25","25-30"]
            y=[100,150,200,250,300,350]
            pack={"Distance":x,"Price":y}
            import pandas as pd
            df=pd.DataFrame(pack)
            print(df)
            while x:
                x=True
                b=int(input("Enter the Distance Position"))
                z=pack["Price"][b]
                c=input("Do you want to give instruction to driver(yes/no)")
                if c=="yes":
                    f=input("Enter the Instructions:")
                else:
                    print("THANK YOU")
                    break
            from colorama import Fore,Back,Style
            print(Fore.RED,Back.YELLOW,Style.BRIGHT+"Pickup Location",pickup)
            print("Drop Location",drop)
            print("Your Total Charge is:",z,"rupees")
            print("Please Pay the Charges")
            print("THANK YOU FOR CHOOSING LPU CAB SERVICES")
            print(Style.RESET_ALL)
        elif a=="Receive":
            pickup=input("Enter the Sender's Address:")
            drop=input("Enter the your Adddress:")
            x=["0-5","5-10","10-15","15-20","20-25","25-30"]
            y=[100,150,200,250,300,350]
            pack={"Distance":x,"Price":y}
            import pandas as pd
            df=pd.DataFrame(pack)
            print(df)
            while x:
                b=int(input("Enter the Distance Position"))
                z=pack["Price"][b]
                c=input("Do you want to give instruction to driver(yes/no)")
                if c=="yes":
                    f=input("Enter the Instructions:")
                else:
                    print("THANK YOU")
                    break
            from colorama import Fore,Back,Style
            print(Fore.RED,Back.YELLOW,Style.BRIGHT+"Pickup Location",pickup)
            print("Drop Location",drop)
            print("Your Total Charge is:",z,"rupees")
            print("Please Pay the Charges")
            print("THANK YOU FOR CHOOSING LPU CAB SERVICES")
            print(Style.RESET_ALL)
        else:
            print("Sorry! Entered Service not Available")
class cab_booking_service:
    def info(self,name=""):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\t\t\tHello!",name,"\t\t\t\t\t\twww.lpu_cabservice\n\t\t\t\t\t Welcome to LPU Cab Service")
        print("\t\t\t\t\t(Providing comfort to your Travel)")
        print(Style.RESET_ALL)
    
    def service(self):
        print("\n\t\t\t\t\t\tTYPES OF SERVICE\n")
        print("1. Intercity: Travel other Cities with LPU Cab Services\n")
        print("2. Intracity: Travel comfortly in your City with LPU Cab Services\n")
        print("3. Package: Send or Recieve Packages from your loved ones, family or friends\n\n\n")

    def intercity(self):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\t\t\tWelcome to LPU Intercity Cab Services\n")
        print(Style.RESET_ALL)
        pickup=input("Enter the Pickup Location:")
        drop=input("Enter the Drop Location:")
        x=["LPU Go","LPU Prime Sedan","LPU Premier"]
        y=[50,100,150]
        ic_={"Available Cab":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(ic_)
        print(df)
        f=[]
        while x:
            x=True
            p=int(input("Enter the Postion of available cab:"))
            d=int(input("Enter the Distance"))
            z=ic_["Price"][p]
            y=z*d
            f.append(y)
            s=input("Enter any instruction you want to give to driver:")
            e=input("Do you want to book a cab again(yes\no)")
            if e=="no":
                print("Thank YOU")
            break
        t=sum(f)
        from colorama import Fore,Back,Style
        print(Fore.BLACK,Back.YELLOW,Style.BRIGHT,"Pickup Location:",pickup,"\nDrop Location:",drop)
        print("Instruction to driver:",s)
        print("Your Total charge is:",t)
        print("Please Pay",t,"rupees")
        print("THNAK YOU FOR CHOOSING LPU CAB SERVICES")
        print(Style.RESET_ALL)
    
    def intracity(self):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\t\tWelcome to LPU Package Services\n")
        print(Style.RESET_ALL)
        pickup=input("Enter the Pickup Location:")
        drop=input("Enter the Drop Location:")
        x=["LPU Go","LPU Auto","LPU Bike"]
        y=[70,50,30]
        ic_={"Available cab":x,"Price":y}
        import pandas as pd
        df=pd.DataFrame(ic_)
        print(df)
        f=[]
        while x:
            x=True
            p=int(input("Enter the Position of Available cab"))
            d=int(input("Enter the Distance"))
            z=ic_["Price"][p]
            y=z*d
            f.append(y)
            s=input("Enter the Instruction to Driver:")
            e=input("Do you want to book a cab again(yes/no)")
            if e=="no":
                print("THANK YOU")
                break
        t=sum(f)
        from colorama import Fore,Back,Style
        print(Fore.BLACK,Back.YELLOW,Style.BRIGHT,"Pickup Location:",pickup,"\nDrop Location:",drop)
        print("Instructions to driver:",s)
        print("Your Total Charge is:",t)
        print("Please Pay",t,"rupees")
        print("TTHANK YOU FOR CHOOSING LPU CAB SERVICES")
        print(Style.RESET_ALL)   
    
    def package(self):
        from colorama import Fore,Style
        print(Fore.BLUE,Style.BRIGHT)
        print("\t\t\t\tWelcome to LPU Package Service\n")
        print(Style.RESET_ALL)
        a=input("Do you want to send or receive a package")
        if a=="send":
            pickup=input("Enter the your Address:")
            drop=input("Enter the Receiver's Adddress:")
            x=["0-5","5-10","10-15","15-20","20-25","25-30"]
            y=[100,150,200,250,300,350]
            pack={"Distance":x,"Price":y}
            import pandas as pd
            df=pd.DataFrame(pack)
            print(df)
            while x:
                x=True
                b=int(input("Enter the Distance Position"))
                z=pack["Price"][b]
                c=input("Do you want to give instruction to driver(yes/no)")
                if c=="yes":
                    f=input("Enter the Instructions:")
                else:
                    print("THANK YOU")
                    break
            from colorama import Fore,Back,Style
            print(Fore.RED,Back.YELLOW,Style.BRIGHT+"Pickup Location",pickup)
            print("Drop Location",drop)
            print("Your Total Charge is:",z,"rupees")
            print("Please Pay the Charges")
            print("THANK YOU FOR CHOOSING LPU CAB SERVICES")
            print(Style.RESET_ALL)
        elif a=="Receive":
            pickup=input("Enter the Sender's Address:")
            drop=input("Enter the your Adddress:")
            x=["0-5","5-10","10-15","15-20","20-25","25-30"]
            y=[100,150,200,250,300,350]
            pack={"Distance":x,"Price":y}
            import pandas as pd
            df=pd.DataFrame(pack)
            print(df)
            while x:
                b=int(input("Enter the Distance Position"))
                z=pack["Price"][b]
                c=input("Do you want to give instruction to driver(yes/no)")
                if c=="yes":
                    f=input("Enter the Instructions:")
                else:
                    print("THANK YOU")
                    break
            from colorama import Fore,Back,Style
            print(Fore.RED,Back.YELLOW,Style.BRIGHT+"Pickup Location",pickup)
            print("Drop Location",drop)
            print("Your Total Charge is:",z,"rupees")
            print("Please Pay the Charges")
            print("THANK YOU FOR CHOOSING LPU CAB SERVICES")
            print(Style.RESET_ALL)
        else:
            print("Sorry! Entered Service not Available")

# %%
obj=cab_booking_service()
obj.info("Mitali")
obj.service()
service=input("Enter the Type of Service You Want:")
if service=="Intercity":
    print("\n\n",obj.intercity())
elif service=="Intracity":
    print("\n\n",obj.intracity())
elif service=="Package":
    print("\n\n",obj.package())
else:
    print("Entered Service Not Available!")
# Out:
#
# 						Hello! Mitali 						www.lpu_cabservice
# 					 Welcome to LPU Cab Service
# 					(Providing comfort to your Travel)
#
#
# 						TYPES OF SERVICE
#
# 1. Intercity: Travel other Cities with LPU Cab Services
#
# 2. Intracity: Travel comfortly in your City with LPU Cab Services
#
# 3. Package: Send or Recieve Packages from your loved ones, family or friends
#
#
#
# Enter the Type of Service You Want:Package
#
# 				Welcome to LPU Package Service
#
#
# Do you want to send or receive a packagesend
# Enter the your Address:117 gopalpura
# Enter the Receiver's Adddress:gujar thadi
#   Distance  Price
# 0      0-5    100
# 1     5-10    150
# 2    10-15    200
# 3    15-20    250
# 4    20-25    300
# 5    25-30    350
# Enter the Distance Position4
# Do you want to give instruction to driver(yes/no)no
# THANK YOU
#   Pickup Location 117 gopalpura
# Drop Location gujar thadi
# Your Total Charge is: 300 rupees
# Please Pay the Charges
# THANK YOU FOR CHOOSING LPU CAB SERVICES
#
#
#
# ...
